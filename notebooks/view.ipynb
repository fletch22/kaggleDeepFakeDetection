# %%
import cv2 as cv
import os
import matplotlib.pylab as plt
import config
import pandas as pd
import os

# train_dir = '/kaggle/input/deepfake-detection-challenge/train_sample_videos/'
train_dir = config.MP4_TRAIN_PATH

fig, ax = plt.subplots(1,1, figsize=(15, 15))
train_video_files = [train_dir + x for x in os.listdir(train_dir)]

# video_file = train_video_files[30]
video_file = os.path.join(train_dir, 'akxoopqjqz.mp4')
cap = cv.VideoCapture(video_file)
success, image = cap.read()
image = cv.cvtColor(image, cv.COLOR_BGR2RGB)
cap.release()   
ax.imshow(image)
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
ax.title.set_text(f"FRAME 0: {video_file.split('/')[-1]}")
plt.grid(False)

# %%
df = pd.read_csv(config.SAMPLE_CSV_PATH)

# %%
print(f"Exists: {os.path.exists(config.METADATA_PATH)}")

train_sample_metadata = pd.read_json(config.METADATA_PATH).T
# Out:
# Exists: False
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-99f897dee451> in <module>
#       1 print(f"Exists: {os.path.exists(config.METADATA_PATH)}")
#       2
# ----> 3 train_sample_metadata = pd.read_json(config.METADATA_PATH).T
#
# c:\users\chris\workspaces\kaggledeepfakedetection\venv\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     590         return json_reader
#     591
# --> 592     result = json_reader.read()
#     593     if should_close:
#     594         try:
#
# c:\users\chris\workspaces\kaggledeepfakedetection\venv\lib\site-packages\pandas\io\json\_json.py in read(self)
#     715             obj = self._get_object_parser(self._combine_lines(data.split("\n")))
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-4b455abf88d9> in <module>
# ----> 1 train_sample_metadata = pd.read_json(os.path.join(config.KAGGLE_DATA_PATH, 'metadata.json')).T
#
# c:\users\chris\workspaces\kaggledeepfakedetection\venv\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     590         return json_reader
#     591
# --> 592     result = json_reader.read()
#     593     if should_close:
#     594         try:
#
# c:\users\chris\workspaces\kaggledeepfakedetection\venv\lib\site-packages\pandas\io\json\_json.py in read(self)
#     715             obj = self._get_object_parser(self._combine_lines(data.split("\n")))
#     716         else:
# ...
